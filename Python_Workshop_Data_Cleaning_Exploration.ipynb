# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("data/dirty_data.csv")

# %%
df.columns
# Out:
# Index(['id', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'room_type', 'price', 'minimum_nights', 'number_of_reviews',
#        'last_review', 'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'rating'],
#       dtype='object')

# %%
df.describe()
# Out:
#             host_id        price  minimum_nights  number_of_reviews  \
# count  1.208000e+03  1208.000000     1208.000000        1208.000000
# mean   9.474827e+05   159.344371        9.150662          78.323675
# std    9.116983e+05   148.716833       23.692776          88.634792
# min    2.787000e+03    20.000000        1.000000           0.000000
# 25%    2.576828e+05    85.000000        2.000000          14.000000
# 50%    7.463835e+05   129.000000        3.000000          43.000000
# 75%    1.470862e+06   195.000000        6.000000         116.000000
# max    1.060985e+07  3000.000000      365.000000         480.000000
#
#         last_review  reviews_per_month  calculated_host_listings_count  \
# count   1158.000000        1158.000000                     1208.000000
# mean   43315.083765           0.926166                        2.225166
# std      585.751133           0.982850                        4.048868
# min    40630.000000           0.010000                        1.000000
# 25%    43321.000000           0.210000                        1.000000
# 50%    43609.000000           0.580000                        1.000000
# 75%    43639.000000           1.330000                        2.000000
# max    43654.000000           7.140000                       28.000000
#
#        availability_365       rating
# count       1208.000000  1208.000000
# mean         165.152318     0.495490
# std          134.035522     0.285933
# min            0.000000     0.000107
# 25%           12.000000     0.260978
# 50%          188.000000     0.496360
# 75%          291.250000     0.730903
# max          365.000000     0.997866

# %%
df.head(10)
# Out:
#       id  host_id    host_name neighbourhood_group       neighbourhood  \
# 0  *2539     2787         John           Brooklynn          Kensington
# 1   2595     2845     Jennifer           Manhattan             Midtown
# 2   3647     4632    Elisabeth           Manhattan              Harlem
# 3   3831     4869  LisaRoxanne           Brooklynn        Clinton Hill
# 4   5022     7192        Laura           Manhattan         East Harlem
# 5   5099     7322        Chris           Manhattan         Murray Hill
# 6   5121     7356        Garon           Brooklynn  Bedford-Stuyvesant
# 7   5178     8967     Shunichi           Manhattan      Hell's Kitchen
# 8   5203     7490    MaryEllen           Manhattan     upper West Side
# 9  *5238     7549          Ben           Manhattan           Chinatown
#
#          room_type  price  minimum_nights  number_of_reviews  last_review  \
# 0    Privaate room    149               1                  9      43392.0
# 1  Entire home/apt    225               1                 45      43606.0
# 2    Privaate room    150               3                  0          NaN
# 3  Entire home/apt     89               1                270      43651.0
# 4  Entire home/apt     80              10                  9      43423.0
# 5  Entire home/apt    200               3                 74      43638.0
# 6    Privaate room     60              45                 49      43013.0
# 7    Privaate room     79               2                430      43640.0
# 8    Privaate room     79               2                118      42937.0
# 9  Entire home/apt    150               1                160      43625.0
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0
# 5               0.59                               1               129
# 6               0.40                               1                 0
# 7               3.47                               1               220
# 8               0.99                               1                 0
# 9               1.33                               4               188
#
#      rating
# 0  0.571896
# 1  0.184032
# 2  0.027267
# 3  0.461664
# 4  0.823074
# 5  0.598772
# 6  0.534678
# 7  0.071079
# 8  0.514239
# 9  0.039280

# %%
df.tail(10)
# Out:
#           id  host_id host_name neighbourhood_group       neighbourhood  \
# 1198  511436  2519356     Darya           Brooklynn        Williamsburg
# 1199  511733  1840766  Samantha           Brooklynn            Bushwick
# 1200  511960  2521848       Gay           Manhattan        East Village
# 1201  512209  2521513       Amy           Brooklynn   Brooklynn Heights
# 1202  512210  2522854      Rich           Brooklynn       Crown Heights
# 1203  512775  2396295   Richard              Queens    Long Island City
# 1204  513343  2528671    Dennis           Brooklynn    Prospect Heights
# 1205  513688  2530670   Tiffany           Brooklynn         Boerum Hill
# 1206  514457  2096690   Richard           Brooklynn  Bedford-Stuyvesant
# 1207  514548  2533991    Amanda           Brooklynn            Bushwick
#
#             room_type  price  minimum_nights  number_of_reviews  last_review  \
# 1198  Entire home/apt     96               3                  1      43246.0
# 1199  Entire home/apt    120               5                  3      42267.0
# 1200  Entire home/apt    160               1                 15      42499.0
# 1201  Entire home/apt    800               3                 60      43466.0
# 1202  Entire home/apt    349               2                320      43638.0
# 1203  Entire home/apt    350               2                182      43627.0
# 1204  Entire home/apt    125              30                  1      41101.0
# 1205  Entire home/apt    350               2                134      43653.0
# 1206  Entire home/apt    150              10                 10      43611.0
# 1207  Entire home/apt    180              30                  0          NaN
#
#       reviews_per_month  calculated_host_listings_count  availability_365  \
# 1198               0.07                               1                 0
# 1199               0.04                               1                 0
# 1200               0.18                               1                 0
# 1201               0.70                               1                67
# 1202               3.85                               1               260
# 1203               2.20                               1               272
# 1204               0.01                               1               341
# 1205               1.56                               1                56
# 1206               0.17                               2               185
# 1207                NaN                               1               352
#
#         rating
# 1198  0.926859
# 1199  0.524938
# 1200  0.648744
# 1201  0.551603
# 1202  0.981318
# 1203  0.424881
# 1204  0.046641
# 1205  0.206727
# 1206  0.482942
# 1207  0.701032

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1208 entries, 0 to 1207
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              1208 non-null   object
#  1   host_id                         1208 non-null   int64
#  2   host_name                       1207 non-null   object
#  3   neighbourhood_group             1208 non-null   object
#  4   neighbourhood                   1208 non-null   object
#  5   room_type                       1208 non-null   object
#  6   price                           1208 non-null   int64
#  7   minimum_nights                  1208 non-null   int64
#  8   number_of_reviews               1208 non-null   int64
#  9   last_review                     1158 non-null   float64
#  10  reviews_per_month               1158 non-null   float64
#  11  calculated_host_listings_count  1208 non-null   int64
#  12  availability_365                1208 non-null   int64
#  13  rating                          1208 non-null   float64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 132.2+ KB

# %%
df.loc[0:100:10]
# Out:
#          id  host_id        host_name neighbourhood_group       neighbourhood  \
# 0     *2539     2787             John           Brooklynn          Kensington
# 10     5295     7702             Lena           Manhattan     upper West Side
# 20     7801    21207            Chaya           Brooklynn        Williamsburg
# 30     9668    32294  Ssameer Or Trip           Manhattan              Harlem
# 40    12192    46978           Edward           Manhattan        East Village
# 50    13808    54275   JT And Tiziana           Brooklynn  Bedford-Stuyvesant
# 60   *15385    60252         Cristina           Brooklynn        Williamsburg
# 70   *16974    65837            Robin           Manhattan         East Harlem
# 80    18764    72014            Lul̼           Brooklynn        Williamsburg
# 90   *20611   961342         Augustin           Brooklynn            Bushwick
# 100   22918    32294  Ssameer Or Trip           Manhattan              Harlem
#
#            room_type  price  minimum_nights  number_of_reviews  last_review  \
# 0      Privaate room    149               1                  9      43392.0
# 10   Entire home/apt    135               5                 53      43638.0
# 20   Entire home/apt    299               3                  9      40905.0
# 30     Privaate room     50               3                242      43617.0
# 40     Privaate room     68               2                245      43637.0
# 50     Privaate room     80               1                112      43632.0
# 60     Privaate room     80               2                 42      43646.0
# 70   Entire home/apt    225               4                190      43639.0
# 80     Privaate room    145               3                 61      43577.0
# 90     Privaate room     65               4                 24      43611.0
# 100    Privaate room     60               3                 11      43468.0
#
#      reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                 0.21                               6               365
# 10                0.43                               1                 6
# 20                0.07                               1                 0
# 30                2.04                               3               355
# 40                2.08                               2                96
# 50                1.01                               3               251
# 60                0.38                               1               263
# 70                1.64                               1               215
# 80                0.54                               4               238
# 90                0.28                               1               317
# 100               0.87                               3               219
#
#        rating
# 0    0.571896
# 10   0.872855
# 20   0.902408
# 30   0.245684
# 40   0.036328
# 50   0.255556
# 60   0.545593
# 70   0.448582
# 80   0.271839
# 90   0.373960
# 100  0.965411

# %%
df['neighbourhood_group'] = df['neighbourhood_group'].replace('Brooklynn', 'Brooklyn')

# %%
df
# Out:
#           id  host_id    host_name neighbourhood_group       neighbourhood  \
# 0      *2539     2787         John            Brooklyn          Kensington
# 1       2595     2845     Jennifer           Manhattan             Midtown
# 2       3647     4632    Elisabeth           Manhattan              Harlem
# 3       3831     4869  LisaRoxanne            Brooklyn        Clinton Hill
# 4       5022     7192        Laura           Manhattan         East Harlem
# ...      ...      ...          ...                 ...                 ...
# 1203  512775  2396295      Richard              Queens    Long Island City
# 1204  513343  2528671       Dennis            Brooklyn    Prospect Heights
# 1205  513688  2530670      Tiffany            Brooklyn         Boerum Hill
# 1206  514457  2096690      Richard            Brooklyn  Bedford-Stuyvesant
# 1207  514548  2533991       Amanda            Brooklyn            Bushwick
#
#             room_type  price  minimum_nights  number_of_reviews  last_review  \
# 0       Privaate room    149               1                  9      43392.0
# 1     Entire home/apt    225               1                 45      43606.0
# 2       Privaate room    150               3                  0          NaN
# 3     Entire home/apt     89               1                270      43651.0
# 4     Entire home/apt     80              10                  9      43423.0
# ...               ...    ...             ...                ...          ...
# 1203  Entire home/apt    350               2                182      43627.0
# 1204  Entire home/apt    125              30                  1      41101.0
# 1205  Entire home/apt    350               2                134      43653.0
# 1206  Entire home/apt    150              10                 10      43611.0
# 1207  Entire home/apt    180              30                  0          NaN
#
#       reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                  0.21                               6               365
# 1                  0.38                               2               355
# 2                   NaN                               1               365
# 3                  4.64                               1               194
# 4                  0.10                               1                 0
# ...                 ...                             ...               ...
# 1203               2.20                               1               272
# 1204               0.01                               1               341
# 1205               1.56                               1                56
# 1206               0.17                               2               185
# 1207                NaN                               1               352
#
#         rating
# 0     0.571896
# 1     0.184032
# 2     0.027267
# 3     0.461664
# 4     0.823074
# ...        ...
# 1203  0.424881
# 1204  0.046641
# 1205  0.206727
# 1206  0.482942
# 1207  0.701032
#
# [1208 rows x 14 columns]

# %%
df['neighbourhood_group'] = df['neighbourhood_group'].replace('  Queens', 'Queens')

# %%
df
# Out:
#           id  host_id    host_name neighbourhood_group       neighbourhood  \
# 0      *2539     2787         John            Brooklyn          Kensington
# 1       2595     2845     Jennifer           Manhattan             Midtown
# 2       3647     4632    Elisabeth           Manhattan              Harlem
# 3       3831     4869  LisaRoxanne            Brooklyn        Clinton Hill
# 4       5022     7192        Laura           Manhattan         East Harlem
# ...      ...      ...          ...                 ...                 ...
# 1203  512775  2396295      Richard              Queens    Long Island City
# 1204  513343  2528671       Dennis            Brooklyn    Prospect Heights
# 1205  513688  2530670      Tiffany            Brooklyn         Boerum Hill
# 1206  514457  2096690      Richard            Brooklyn  Bedford-Stuyvesant
# 1207  514548  2533991       Amanda            Brooklyn            Bushwick
#
#             room_type  price  minimum_nights  number_of_reviews  last_review  \
# 0       Privaate room    149               1                  9      43392.0
# 1     Entire home/apt    225               1                 45      43606.0
# 2       Privaate room    150               3                  0          NaN
# 3     Entire home/apt     89               1                270      43651.0
# 4     Entire home/apt     80              10                  9      43423.0
# ...               ...    ...             ...                ...          ...
# 1203  Entire home/apt    350               2                182      43627.0
# 1204  Entire home/apt    125              30                  1      41101.0
# 1205  Entire home/apt    350               2                134      43653.0
# 1206  Entire home/apt    150              10                 10      43611.0
# 1207  Entire home/apt    180              30                  0          NaN
#
#       reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                  0.21                               6               365
# 1                  0.38                               2               355
# 2                   NaN                               1               365
# 3                  4.64                               1               194
# 4                  0.10                               1                 0
# ...                 ...                             ...               ...
# 1203               2.20                               1               272
# 1204               0.01                               1               341
# 1205               1.56                               1                56
# 1206               0.17                               2               185
# 1207                NaN                               1               352
#
#         rating
# 0     0.571896
# 1     0.184032
# 2     0.027267
# 3     0.461664
# 4     0.823074
# ...        ...
# 1203  0.424881
# 1204  0.046641
# 1205  0.206727
# 1206  0.482942
# 1207  0.701032
#
# [1208 rows x 14 columns]

# %%
df['room_type'] = df['room_type'].replace('Privaate Room', 'Private Room')

# %%
df
# Out:
#           id  host_id    host_name neighbourhood_group       neighbourhood  \
# 0      *2539     2787         John            Brooklyn          Kensington
# 1       2595     2845     Jennifer           Manhattan             Midtown
# 2       3647     4632    Elisabeth           Manhattan              Harlem
# 3       3831     4869  LisaRoxanne            Brooklyn        Clinton Hill
# 4       5022     7192        Laura           Manhattan         East Harlem
# ...      ...      ...          ...                 ...                 ...
# 1203  512775  2396295      Richard              Queens    Long Island City
# 1204  513343  2528671       Dennis            Brooklyn    Prospect Heights
# 1205  513688  2530670      Tiffany            Brooklyn         Boerum Hill
# 1206  514457  2096690      Richard            Brooklyn  Bedford-Stuyvesant
# 1207  514548  2533991       Amanda            Brooklyn            Bushwick
#
#             room_type  price  minimum_nights  number_of_reviews  last_review  \
# 0       Privaate room    149               1                  9      43392.0
# 1     Entire home/apt    225               1                 45      43606.0
# 2       Privaate room    150               3                  0          NaN
# 3     Entire home/apt     89               1                270      43651.0
# 4     Entire home/apt     80              10                  9      43423.0
# ...               ...    ...             ...                ...          ...
# 1203  Entire home/apt    350               2                182      43627.0
# 1204  Entire home/apt    125              30                  1      41101.0
# 1205  Entire home/apt    350               2                134      43653.0
# 1206  Entire home/apt    150              10                 10      43611.0
# 1207  Entire home/apt    180              30                  0          NaN
#
#       reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                  0.21                               6               365
# 1                  0.38                               2               355
# 2                   NaN                               1               365
# 3                  4.64                               1               194
# 4                  0.10                               1                 0
# ...                 ...                             ...               ...
# 1203               2.20                               1               272
# 1204               0.01                               1               341
# 1205               1.56                               1                56
# 1206               0.17                               2               185
# 1207                NaN                               1               352
#
#         rating
# 0     0.571896
# 1     0.184032
# 2     0.027267
# 3     0.461664
# 4     0.823074
# ...        ...
# 1203  0.424881
# 1204  0.046641
# 1205  0.206727
# 1206  0.482942
# 1207  0.701032
#
# [1208 rows x 14 columns]
